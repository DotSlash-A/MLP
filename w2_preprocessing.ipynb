# %%
data = [{'age' : 4, 'height' : 96.0, 'distance' : 23},
        {'age' : 1, 'height' : 73.9, 'distance' : 45},
        {'age' : 3, 'height' : 88.9, 'distance' :np.nan},
        {'age' : 2, 'height' : 81.6, 'distance' :30}]

# %% [markdown]
# # Lec-1

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)
x = dv.fit_transform(data)
print(x)
# Out:
# [[ 4.  23.  96. ]
#  [ 1.  45.  73.9]
#  [ 3.   nan 88.9]
#  [ 2.  30.  81.6]]

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy='mean')
si.fit_transform(x)
# Out:
# array([[ 4.        , 23.        , 96.        ],
#        [ 1.        , 45.        , 73.9       ],
#        [ 3.        , 32.66666667, 88.9       ],
#        [ 2.        , 30.        , 81.6       ]])

# %%
data_knn = [{'age' : 4, 'height' : 96.0, 'distance' : 23},
        {'age' : 1, 'height' : 73.9, 'distance' : 45},
        {'age' : 3, 'height' : 88.9, 'distance' :np.nan},
        {'age' : 2, 'height' : 81.6, 'distance' :30}]

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)
x = dv.fit_transform(data)
print(x)
# Out:
# [[ 4.  23.  96. ]
#  [ 1.  45.  73.9]
#  [ 3.   nan 88.9]
#  [ 2.  30.  81.6]]

# %%
x
# Out:
# array([[ 4. , 23. , 96. ],
#        [ 1. , 45. , 73.9],
#        [ 3. ,  nan, 88.9],
#        [ 2. , 30. , 81.6]])

# %%
from sklearn.impute import KNNImputer
knni = KNNImputer(n_neighbors = 1, weights = "uniform")
knni.fit_transform(x)

# %%
from sklearn.impute import KNNImputer
knni = KNNImputer(n_neighbors = 1, weights = "uniform")
knni.fit_transform(x)

# %%
from sklearn.impute import KNNImputer
knni = KNNImputer(n_neighbors = 3, weights = "uniform")
knni.fit_transform(x)

# %% [markdown]
# ## AQ: 2.1

# %%
 data_aq = [{'#courses_opted': 4, 'GPA': 6.7},{'#courses_opted': 4, 'GPA': 8.5},
         {'#courses_opted': 2, 'GPA': 8.1},{'#courses_opted': 1, 'GPA': 7.2},
         {'#courses_opted': 1, 'GPA': 9.1}]

# %%
 from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)
data_transformed = dv.fit_transform(data)
data_transformed[:2]

# %% [markdown]
# # Lec 2

# %%
from sklearn.preprocessing import StandardScaler

# %%
x = np.array([4,3,2,5,6])
x.reshape(1,-1)
# Out:
# array([[4, 3, 2, 5, 6]])

# %%
a = np.array([[1,2,4],[10,20,30],[23,17,47]])

# %%
np.mean(a)
# Out:
# 17.11111111111111

# %%
ss = StandardScaler()
ss.fit_transform(a)
# Out:
# array([[-1.14423088, -1.3970014 , -1.30072966],
#        [-0.14764269,  0.88900089,  0.16966039],
#        [ 1.29187357,  0.50800051,  1.13106927]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
print(a)
# Out:
# [[ 1  2  4]
#  [10 20 30]
#  [23 17 47]]

# %%
mms = MinMaxScaler()
mms.fit_transform(a)
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.40909091, 1.        , 0.60465116],
#        [1.        , 0.83333333, 1.        ]])

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mas= MaxAbsScaler()
mas.fit_transform(a,)
# Out:
# array([[0.04347826, 0.1       , 0.08510638],
#        [0.43478261, 1.        , 0.63829787],
#        [1.        , 0.85      , 1.        ]])

# %%
# ?MaxAbsScaler

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=2)
pf.fit_transform(x)

# %%
x = np.array([0,3,6])
print(np.mean(x))

print(np.std(x))
# Out:
# 3.0
# 6.0
# 2.449489742783178

# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np

X = np.array([[1], [2], [3]])
ft = FunctionTransformer(np.mean)
ft.fit_transform(X)
# Out:
# 2.0

# %%
X
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
ft
# Out:
# FunctionTransformer(func=<function mean at 0x000001F93E70B5E0>)

# %% [markdown]
# # PA

# %%
data_url = 'https://docs.google.com/spreadsheets/d/1XePXtNHcvJpCxAp4F7i8upB1QLTQJG7-/edit?usp=sharing&ouid=103622359275953448721&rtpof=true&sd=true'


data = pd.read_csv(data_url, sep = ";")
data.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-4beb90a18954> in <module>
#       2
#       3
# ----> 4 data = pd.read_csv(data_url, sep = ";")
#       5 data.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
import pandas as pd
data_url = 'https://drive.google.com/file/d/1lvvHj0v9LKwe6XUezgpIUY_c0HdJUcCb/view'

data = pd.read_csv(data_url, sep = ";")
data.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-8c3e5ed5c489> in <module>
#       1 data_url = 'https://drive.google.com/file/d/1lvvHj0v9LKwe6XUezgpIUY_c0HdJUcCb/view'
#       2
# ----> 3 data = pd.read_csv(data_url, sep = ";")
#       4 data.head()
#
# ...

# %%
dataset = pd.read_csv("DataPreprocessingGraded_dataset.csv")

# %%
dataset.head()
# Out:
#     V1    V2       V3    V4        V5 Target
# 0  2.0  50.0  12500.0  98.0  NEGATIVE    YES
# 1  0.0  13.0   3250.0  28.0  NEGATIVE    YES
# 2    ?     ?   4000.0  35.0  NEGATIVE    YES
# 3    ?  20.0   5000.0  45.0  NEGATIVE    YES
# 4  1.0  24.0   6000.0  77.0  NEGATIVE     NO

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (748, 6)

# %%
dataset.target_labels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c33c9d98be77> in <module>
# ----> 1 dataset.target_labels
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target_labels'

# %%
dataset.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'Target'], dtype='object')
