# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]])
b = np.array([[7,8],[9,10],[11,12]])

# %%
import numpy as np
c = int(input())
r = int(input())
x = np.zeros([c,r])
print(x)
# Out:
# [[0. 0. 0. 0. 0.]]

# %%
numpy_array = np.array([4,4])

# %%
def mean(numpy_array):
    print((c+r)/2)
mean(numpy_array)
# Out:
# 3.0
